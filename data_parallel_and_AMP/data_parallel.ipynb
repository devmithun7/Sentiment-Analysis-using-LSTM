# %%
# !python main.py 8
# Out:
# Started Main Execution
# Client Dashboard:  http://127.0.0.1:8787/status
# 2024-12-12 14:29:05,533 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2024-12-12 14:29:05,541 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2024-12-12 14:29:05,546 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2024-12-12 14:29:05,551 - distributed.nanny - WARNING - Worker process still alive after 4.0 seconds, killing
# 2024-12-12 14:29:06,080 - INFO - Starting distributed training with the following parameters:
# Starting distributed training with the following parameters:
# 2024-12-12 14:29:06,081 - INFO - Sequence length: 200
# Sequence length: 200
# 2024-12-12 14:29:06,082 - INFO - Batch size: 32
# Batch size: 32
# 2024-12-12 14:29:06,082 - INFO - Number of epochs: 3
# Number of epochs: 3
# 2024-12-12 14:29:06,083 - INFO - World size: 8
# World size: 8
# ...

# %%
# !python main.py 12

# %%
# !python main.py 16

# %%
# !python main.py 20

# %%
# !python main.py 24

# %%
# !python main.py 28
